# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
time = np.array([3.4365310668945312,
                 1.8143439292907715,
                 1.2134535312652588,
                 1.011009931564331,
                 0.7168467044830322,
                 0.669912576675415,
                 0.5913188457489014,
                 0.5408780574798584,
                 0.48679542541503906,
                 0.44424986839294434,
                 0.415529727935791,
                 0.3681631088256836,
                 0.35811352729797363,
                 0.2830197811126709,
                 0.24335241317749023,
                 0.2270965576171875,
                 0.2328789234161377,
                 0.251446008682251,
                 0.2357335090637207,
                 0.23085975646972656])
n = [i for i in range(1, 21)]
plt.plot(n, time)
plt.xlabel('Number of Cores')
plt.ylabel('Computation Time')
plt.title('Computation Time VS Number of Cores')
plt.savefig("health_simulation_mpi.png")
